# %% [markdown]
# <a href="https://colab.research.google.com/github/among5094/Big-Data-Integrated-Analysis/blob/main/week03_CH03_%ED%8C%90%EB%8B%A4%EC%8A%A4_%EB%9D%BC%EC%9D%B4%EB%B8%8C%EB%9F%AC%EB%A6%AC%EC%9D%98_%EA%B0%9C%EC%9A%94/CH03%EC%9E%A5_%EC%97%B0%EC%8A%B5%EB%AC%B8%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## CH03장 연습문제

# %% [markdown]
# ### 1번

# %%
import pandas as pd

# 조건1) 보기의 데이터프레임을 생성하고, df 변수에 할당한다.
df=pd.DataFrame([['버거킹', '5000', '5.0'],
                ['맥도날드', '4500', '4.5'],
                ['롯데리아', '5000', '4.3']])
df
# Out:
#       0     1    2
# 0   버거킹  5000  5.0
# 1  맥도날드  4500  4.5
# 2  롯데리아  5000  4.3

# %%
# 칼럼명 변경하기
df.columns=['장소', '가격', '평점']
df
# Out:
#      장소    가격   평점
# 0   버거킹  5000  5.0
# 1  맥도날드  4500  4.5
# 2  롯데리아  5000  4.3

# %% [markdown]
# ### 2번

# %%
import pandas as pd
import seaborn as sns

tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ##### 2-1번 : 팁이 7달러 이상인 데이터 추출

# %%
tips[tips['tip']>=7]
# Out:
#      total_bill    tip   sex smoker  day    time  size
# 23        39.42   7.58  Male     No  Sat  Dinner     4
# 170       50.81  10.00  Male    Yes  Sat  Dinner     3
# 212       48.33   9.00  Male     No  Sat  Dinner     4

# %% [markdown]
# ##### 2-2번 : 여성 손님이면서 비흡연자인 데이터 찾기

# %%
conditions = (tips['sex']=='Female') & (tips['smoker']=='No')
tips[conditions].head()
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 16       10.33  1.67  Female     No  Sun  Dinner     3

# %% [markdown]
# 1. string형은 꼭 '' 붙이기
# 2. 비교할 때는 각 조건에 괄호 씌워주기

# %% [markdown]
# ##### 2-3번 : 팁을 가장 많이 지불한 고객 찾기

# %%
tips[ tips['tip']==tips['tip'].max() ]
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 170       50.81  10.0  Male    Yes  Sat  Dinner     3

# %% [markdown]
# ##### 2-4번 : 팁을 가장 많이 지불한 고객 찾기(문제가 틀린것같음)

# %%
tips.loc[ tips.sort_values(['total_bill', 'tip'], ascending=False).index[:10] ]
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4
# 142       41.19   5.00    Male     No  Thur   Lunch     5
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4

# %%
# 이것도 방법이긴하나 문제의 조건은 tips[] 이 형태여야함
tips.sort_values(['total_bill', 'tip'], ascending=False).head(10)
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4
# 142       41.19   5.00    Male     No  Thur   Lunch     5
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4

# %% [markdown]
# ##### 2-5번 : size를 기준으로 내림차, tip을 기준으로 오름차 정렬한 결과 상위 10개 데이터만 추출하기

# %%
tips.sort_values(['size', 'tip'], ascending=[False,True]).head(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 125       29.80  4.20  Female     No  Thur   Lunch     6
# 143       27.05  5.00  Female     No  Thur   Lunch     6
# 156       48.17  5.00    Male     No   Sun  Dinner     6
# 141       34.30  6.70    Male     No  Thur   Lunch     6
# 187       30.46  2.00    Male    Yes   Sun  Dinner     5
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5
# 142       41.19  5.00    Male     No  Thur   Lunch     5
# 185       20.69  5.00    Male     No   Sun  Dinner     5
# 155       29.85  5.14  Female     No   Sun  Dinner     5
# 153       24.55  2.00    Male     No   Sun  Dinner     4

# %% [markdown]
# ##### 2-6번 : total_bill과 tip 합계인 total 칼럼 생성하기

# %%
tips['total'] = tips['total_bill'] + tips['tip']
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  total
# 0         16.99  1.01  Female     No   Sun  Dinner     2  18.00
# 1         10.34  1.66    Male     No   Sun  Dinner     3  12.00
# 2         21.01  3.50    Male     No   Sun  Dinner     3  24.51
# 3         23.68  3.31    Male     No   Sun  Dinner     2  26.99
# 4         24.59  3.61  Female     No   Sun  Dinner     4  28.20
# ..          ...   ...     ...    ...   ...     ...   ...    ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  34.95
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  29.18
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  24.67
# 242       17.82  1.75    Male     No   Sat  Dinner     2  19.57
# 243       18.78  3.00  Female     No  Thur  Dinner     2  21.78
#
# [244 rows x 8 columns]

# %% [markdown]
# ##### 2-7번 : 다음은 day별 tip의 평균 출력

# %% [markdown]
# 문제를 풀기위해 데이터에 대한 이해가 필요하다고 느낌. 아래의 데이터는 메타데이터에 대한 이해를 위해 작성된 것

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  total
# 0       16.99  1.01  Female     No  Sun  Dinner     2  18.00
# 1       10.34  1.66    Male     No  Sun  Dinner     3  12.00
# 2       21.01  3.50    Male     No  Sun  Dinner     3  24.51

# %%
tips['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
pd.DataFrame(tips.groupby('day'))
# Out:
# <ipython-input-13-3dcb0806d8a4>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   pd.DataFrame(tips.groupby('day'))
#       0                                                  1
# 0  Thur       total_bill   tip     sex smoker   day    ...
# 1   Fri       total_bill   tip     sex smoker  day    t...
# 2   Sat       total_bill   tip     sex smoker  day    t...
# 3   Sun       total_bill   tip     sex smoker  day    t...

# %%
pd.DataFrame(tips.groupby('day')['tip'].mean() )
# Out:
# <ipython-input-14-8753620f3e66>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   pd.DataFrame(tips.groupby('day')['tip'].mean() )
#            tip
# day
# Thur  2.771452
# Fri   2.734737
# Sat   2.993103
# Sun   3.255132

# %% [markdown]
# - 오답:
# pd.DataFrame(tips['tip'].mean().sort_values('day') )
#
# 여기서 tips['tip'].mean() 은  tip 전체의 평균값 **하나**만 구함.
#
# - 정답: day 별로 그룹화 → 각 그룹에서 tip 평균 구하기

# %% [markdown]
# ### 3번

# %% [markdown]
# ##### 3-1번 : tips 데이터셋 중 day가 금요일(Rri), 토요일(Sat)만 필터링한다.

# %%
tips[(tips['day']=='Fri')|(tips['day']=='Sat')]
# Out:
#      total_bill   tip     sex smoker  day    time  size  total
# 19        20.65  3.35    Male     No  Sat  Dinner     3  24.00
# 20        17.92  4.08    Male     No  Sat  Dinner     2  22.00
# 21        20.29  2.75  Female     No  Sat  Dinner     2  23.04
# 22        15.77  2.23  Female     No  Sat  Dinner     2  18.00
# 23        39.42  7.58    Male     No  Sat  Dinner     4  47.00
# ..          ...   ...     ...    ...  ...     ...   ...    ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3  40.50
# 239       29.03  5.92    Male     No  Sat  Dinner     3  34.95
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2  29.18
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2  24.67
# 242       17.82  1.75    Male     No  Sat  Dinner     2  19.57
#
# [106 rows x 8 columns]

# %% [markdown]
# ##### 3-2번 : tip이 평균보다 많게 낸 데이터만 필터링

# %%
tips[tips['tip']>=tips['tip'].mean()]
# Out:
#      total_bill   tip     sex smoker   day    time  size  total
# 2         21.01  3.50    Male     No   Sun  Dinner     3  24.51
# 3         23.68  3.31    Male     No   Sun  Dinner     2  26.99
# 4         24.59  3.61  Female     No   Sun  Dinner     4  28.20
# 5         25.29  4.71    Male     No   Sun  Dinner     4  30.00
# 7         26.88  3.12    Male     No   Sun  Dinner     4  30.00
# ..          ...   ...     ...    ...   ...     ...   ...    ...
# 232       11.61  3.39    Male     No   Sat  Dinner     2  15.00
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2  18.53
# 238       35.83  4.67  Female     No   Sat  Dinner     3  40.50
# 239       29.03  5.92    Male     No   Sat  Dinner     3  34.95
# 243       18.78  3.00  Female     No  Thur  Dinner     2  21.78
#
# [121 rows x 8 columns]

# %% [markdown]
# 작동원리:
# - tips[tips['tip']>=tips['tip'].mean()]는
# 안에 조건들 때문에 불리언 시리즈들이 만들어지고 여기서 True랑 False가 나뉨.
# - 그리고 True가 되는것만 추출됨.
# - 불리언 시리즈를 만들게 하는 건 >=(비교연산자) 때문임

# %% [markdown]
# ##### 3-3번 : 칼럼은 total_bill, tip, time, total만 출력하기

# %%
tips[['total_bill', 'tip', 'time', 'total']]
# Out:
#      total_bill   tip    time  total
# 0         16.99  1.01  Dinner  18.00
# 1         10.34  1.66  Dinner  12.00
# 2         21.01  3.50  Dinner  24.51
# 3         23.68  3.31  Dinner  26.99
# 4         24.59  3.61  Dinner  28.20
# ..          ...   ...     ...    ...
# 239       29.03  5.92  Dinner  34.95
# 240       27.18  2.00  Dinner  29.18
# 241       22.67  2.00  Dinner  24.67
# 242       17.82  1.75  Dinner  19.57
# 243       18.78  3.00  Dinner  21.78
#
# [244 rows x 4 columns]

# %% [markdown]
# ##### 3-4번 : total이 높은 상위 10개 행만 추출함

# %%
tips.sort_values('total', ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size  total
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3  60.81
# 212       48.33   9.00    Male     No   Sat  Dinner     4  57.33
# 59        48.27   6.73    Male     No   Sat  Dinner     4  55.00
# 156       48.17   5.00    Male     No   Sun  Dinner     6  53.17
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3  48.85
# ..          ...    ...     ...    ...   ...     ...   ...    ...
# 218        7.74   1.44    Male    Yes   Sat  Dinner     2   9.18
# 195        7.56   1.44    Male     No  Thur   Lunch     2   9.00
# 111        7.25   1.00  Female     No   Sat  Dinner     1   8.25
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2   6.75
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1   4.07
#
# [244 rows x 8 columns]
