# %% [markdown]
# <a href="https://colab.research.google.com/github/among5094/Big-Data-Integrated-Analysis/blob/main/week03_CH03_%ED%8C%90%EB%8B%A4%EC%8A%A4_%EB%9D%BC%EC%9D%B4%EB%B8%8C%EB%9F%AC%EB%A6%AC%EC%9D%98_%EA%B0%9C%EC%9A%94/3week_0324_mon_ipynb__.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CH03 판다스 라이브러리 개요

# %% [markdown]
# ### 날짜: 3월 24일 월요일( 3주차 )

# %% [markdown]
# ### 3.1 판다스 데이터의 구조 이해
#
# 판다스(Pandas)는 파이썬에서 데이터를 쉽게 다룰 수 있도록 만든 라이브러리
# 우리가 자주 사용하는 자료구조(data structure) 두 개있음.
#
# (1) 시리즈
# - 1차원 데이터 구조로, 리스트나 배열과 비슷하지만 각 요소에 인덱스(index)를 붙일 수 있음.
# - 1차원: 한 줄짜리 데이터 (열 하나)
# - **인덱스(index)**와 값(value) 두 요소로 구성
# - pd.Series()를 사용해 생성
# - **인덱스를 숫자 대신 문자열 등으로 설정 가능**
#
#
# (2) 데이터프레임
# - 2차원 데이터 구조로, 행(row)과 열(column)로 구성된 엑셀 표와 같은 형태의 자료.
# - 여러 개의 시리즈를 합쳐서 만든 것
# - pd.DataFrame()으로 생성
# - 행(row): 개별 데이터
# - 열(column): 변수나 속성
# - 인덱스(index): 행을 구분하는 값

# %%
# 판다스 패키지 설치
# pip install pandas

# %%
# 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 임포트
import pandas as pd

# %%
# 시리즈 만들기
name = pd.Series(['jang', 'yang', 'oh'])
name
# Out:
# 0    jang
# 1    yang
# 2      oh
# dtype: object

# %% [markdown]
# ### 3.2 데이터프레임 객체 생성하기

# %% [markdown]
# ##### 3.2 (1) 데이터프레임 직접 생성하기

# %%
df=pd.DataFrame({'name':['jang','yang','oh'],
                'dept':['com','eng','math'],
                'score':['100','90','95']})

# %%
# 딕셔너리로 데이터프레임  생성하기
df=pd.DataFrame({'name':['jang','yang','oh'], #리스트
                  'dept':['com','eng','math'], #리스트
                  'score':['100','90','95']}) #리스트
df
# Out:
#    name  dept score
# 0  jang   com   100
# 1  yang   eng    90
# 2    oh  math    95

# %% [markdown]
# Q. 리스트와 튜플은 공존할 수 있는가?
# A. Yes, 이유는 데이터를 열 단위로 넣기만 하면 된다.
# - 판다스는 리스트든 튜플이든 **순서대로** 데이터를 읽어서 열을 생성할 수 있음
# - 또, 리스트와 튜플은 "**순서가 있는 자료형**"이라서 판다스가 행마다 잘 매칭해서 읽을 수 있음!
# 단, 모든 열의 길이는 같아야됨!

# %%
df = pd.DataFrame({
    'name': ('jang', 'yang', 'oh'),       # 튜플도 가능!
    'dept': ['com', 'eng', 'math'],       # 리스트
    'score': ('100', '90', '95')          # 튜플
})

# %% [markdown]
# ##### 3.2 (2) 외부 데이터 이용하기

# %%
# 외부데이터 이용하기 - 1. csv파일 불러오기
df = pd.read_csv('/content/drive/MyDrive/data/exam.csv')
df
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
# 외부데이터 이용하기 - 2. 엑셀파일 불러오기
df2 = pd.read_excel('/content/drive/MyDrive/data/code.xlsx')
df2
# Out:
#   학과코드   학과명
# 0  A01   컴퓨터
# 1  A02    국문
# 2  A03    영문
# 3  A04    경영
# 4  A05    경제
# 5  A06  전자공학
# 6  A07  기계설비
# 7  A99   디자인

# %% [markdown]
# ### 3.3 데이터 확인하기

# %%
# 데이터 프레임 만들기
filename = '/content/drive/MyDrive/data/music.csv'
df = pd.read_csv(filename)
df
# Out:
#        title singer  personnel sortation release_date                 agency  \
# 0        좋은날    아이유          1        솔로   2010-12-09              카카오엔터테인먼트
# 1    내가제일잘나가   2NE1          4        그룹   2011-06-24               YG엔터테인먼트
# 2      강남스타일     싸이          1        솔로   2012-07-15               YG엔터테인먼트
# 3       첫사랑니   f(x)          5        그룹   2013-07-29               SM엔터테인먼트
# 4        위아래   EXID          4        그룹   2014-08-27                  바나나컬쳐
# 5    Ah-Choo   러블리즈          8        그룹   2015-10-01               울림엔터테인먼트
# 6       피땀눈물  방탄소년단          7        그룹   2016-10-10                  빅히트뮤직
# 7     시간을달려서   여자친구          6        그룹   2016-01-25                   쏘스뮤직
# 8        빨간맛   레드벨벳          5        그룹   2017-07-09               SM엔터테인먼트
# 9       에너제틱    워너원         11        그룹   2017-08-07  YMC엔터테인먼트, 스톤뮤직엔터테인먼트
# 10      뚜두뚜두   블랙핑크          4        그룹   2018-06-15               YG엔터테인먼트
# ...

# %%
df.info() # 데이터 변수 속성 확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         13 non-null     object
#  1   singer        13 non-null     object
#  2   personnel     13 non-null     int64
#  3   sortation     13 non-null     object
#  4   release_date  13 non-null     object
#  5   agency        13 non-null     object
#  6   genre         13 non-null     object
#  7   type          13 non-null     object
# dtypes: int64(1), object(7)
# memory usage: 964.0+ bytes

# %%
df.head() # 앞에서부터 5행까지 출력
# Out:
#      title singer  personnel sortation release_date     agency genre type
# 0      좋은날    아이유          1        솔로   2010-12-09  카카오엔터테인먼트   발라드   EP
# 1  내가제일잘나가   2NE1          4        그룹   2011-06-24   YG엔터테인먼트    댄스   싱글
# 2    강남스타일     싸이          1        솔로   2012-07-15   YG엔터테인먼트    힙합   정규
# 3     첫사랑니   f(x)          5        그룹   2013-07-29   SM엔터테인먼트    댄스   정규
# 4      위아래   EXID          4        그룹   2014-08-27      바나나컬쳐    댄스   싱글

# %%
df.head(10) # 숫자만큼만 위에서 10개의 데이터 보기
# Out:
#      title singer  personnel sortation release_date                 agency  \
# 0      좋은날    아이유          1        솔로   2010-12-09              카카오엔터테인먼트
# 1  내가제일잘나가   2NE1          4        그룹   2011-06-24               YG엔터테인먼트
# 2    강남스타일     싸이          1        솔로   2012-07-15               YG엔터테인먼트
# 3     첫사랑니   f(x)          5        그룹   2013-07-29               SM엔터테인먼트
# 4      위아래   EXID          4        그룹   2014-08-27                  바나나컬쳐
# 5  Ah-Choo   러블리즈          8        그룹   2015-10-01               울림엔터테인먼트
# 6     피땀눈물  방탄소년단          7        그룹   2016-10-10                  빅히트뮤직
# 7   시간을달려서   여자친구          6        그룹   2016-01-25                   쏘스뮤직
# 8      빨간맛   레드벨벳          5        그룹   2017-07-09               SM엔터테인먼트
# 9     에너제틱    워너원         11        그룹   2017-08-07  YMC엔터테인먼트, 스톤뮤직엔터테인먼트
#
#   genre type
# 0   발라드   EP
# 1    댄스   싱글
# 2    힙합   정규
# 3    댄스   정규
# 4    댄스   싱글
# 5    댄스   EP
# 6   R&B   정규
# 7    댄스   EP
# ...

# %%
df.tail() # 앞에서부터 5행까지 출력
# Out:
#        title singer  personnel sortation release_date                 agency  \
# 8        빨간맛   레드벨벳          5        그룹   2017-07-09               SM엔터테인먼트
# 9       에너제틱    워너원         11        그룹   2017-08-07  YMC엔터테인먼트, 스톤뮤직엔터테인먼트
# 10      뚜두뚜두   블랙핑크          4        그룹   2018-06-15               YG엔터테인먼트
# 11      달라달라     있지          5        그룹   2019-02-12              JYP엔터테인먼트
# 12  Dynamite  방탄소년단          7        그룹   2020-08-21                  빅히트뮤직
#
#    genre type
# 8     댄스   EP
# 9     댄스   EP
# 10    댄스   EP
# 11    댄스   싱글
# 12    댄스   싱글

# %% [markdown]
# ##### 3.1.4 데이터 요약 통계량 출력하기

# %%
df.describe() # 숫자 데이터이 전체적인 분포와 특징 보기
# count() 결칙치 제외한 데이터개수
# Out:
#        personnel
# count  13.000000
# mean    5.230769
# std     2.712743
# min     1.000000
# 25%     4.000000
# 50%     5.000000
# 75%     7.000000
# max    11.000000

# %%
# 문자형 데이터(= object 타입) 에 대한 기초 통계 요약 정보
df.describe(include='object')
# Out:
#        title singer sortation release_date    agency genre type
# count     13     13        13           13        13    13   13
# unique    13     12         2           13         9     4    3
# top      좋은날  방탄소년단        그룹   2010-12-09  YG엔터테인먼트    댄스   EP
# freq       1      2        11            1         3    10    6

# %%
# 모든 칼럼의 요약 통계량 확인하기
df.describe(include='all')
# Out:
#        title singer  personnel sortation release_date    agency genre type
# count     13     13  13.000000        13           13        13    13   13
# unique    13     12        NaN         2           13         9     4    3
# top      좋은날  방탄소년단        NaN        그룹   2010-12-09  YG엔터테인먼트    댄스   EP
# freq       1      2        NaN        11            1         3    10    6
# mean     NaN    NaN   5.230769       NaN          NaN       NaN   NaN  NaN
# std      NaN    NaN   2.712743       NaN          NaN       NaN   NaN  NaN
# min      NaN    NaN   1.000000       NaN          NaN       NaN   NaN  NaN
# 25%      NaN    NaN   4.000000       NaN          NaN       NaN   NaN  NaN
# 50%      NaN    NaN   5.000000       NaN          NaN       NaN   NaN  NaN
# 75%      NaN    NaN   7.000000       NaN          NaN       NaN   NaN  NaN
# max      NaN    NaN  11.000000       NaN          NaN       NaN   NaN  NaN

# %% [markdown]
# ##### 3.1.5 데이터 행/열 크기 확인하기

# %%
df.shape
# Out:
# (13, 8)

# %% [markdown]
# ##### 3.1.6 데이터 인덱스/컬럼 명 확인하기

# %%
df.index # 데이터프레임의 "행 인덱스" 정보
"""
start=0 // 인덱스 시작값 (처음 행의 번호)
stop=13 // 인덱스 끝 직전까지 (13은 포함 안 됨)
step=1 // 인덱스 간격 (1씩 증가)
"""
# Out:
# '\nstart=0 // 인덱스 시작값 (처음 행의 번호)\nstop=13 // 인덱스 끝 직전까지 (13은 포함 안 됨)\nstep=1 // 인덱스 간격 (1씩 증가)\n'

# %%
df.columns # 컬럼명 확인
# dtype='object'은 컬럼 이름 자체의 타입이지, 컬럼 속 데이터의 타입은 아님!
# Out:
# Index(['title', 'singer', 'personnel', 'sortation', 'release_date', 'agency',
#        'genre', 'type'],
#       dtype='object')

# %%
df.dtypes # 데이터 타입 출력
# Out:
# title           object
# singer          object
# personnel        int64
# sortation       object
# release_date    object
# agency          object
# genre           object
# type            object
# dtype: object

# %% [markdown]
# ##### 3.1.8 데이터 정렬하기
#
# 기본 문법
# df.sort_values(by='컬럼명', ascending=True, inplace=False)
#
# - by : 기준이 되는 컬럼 이름 (정렬 기준)
# - ascending=True : 오름차순 정렬 (내림차순 하고 싶으면 False)
# - inplace=False : 원본을 바꾸지 않고 새로운 정렬된 DataFrame 반환 (True로 하면 원본 변경됨)

# %%
df.sort_values('release_date') # 데이터 오름차순 정렬
# Out:
#        title singer  personnel sortation release_date                 agency  \
# 0        좋은날    아이유          1        솔로   2010-12-09              카카오엔터테인먼트
# 1    내가제일잘나가   2NE1          4        그룹   2011-06-24               YG엔터테인먼트
# 2      강남스타일     싸이          1        솔로   2012-07-15               YG엔터테인먼트
# 3       첫사랑니   f(x)          5        그룹   2013-07-29               SM엔터테인먼트
# 4        위아래   EXID          4        그룹   2014-08-27                  바나나컬쳐
# 5    Ah-Choo   러블리즈          8        그룹   2015-10-01               울림엔터테인먼트
# 7     시간을달려서   여자친구          6        그룹   2016-01-25                   쏘스뮤직
# 6       피땀눈물  방탄소년단          7        그룹   2016-10-10                  빅히트뮤직
# 8        빨간맛   레드벨벳          5        그룹   2017-07-09               SM엔터테인먼트
# 9       에너제틱    워너원         11        그룹   2017-08-07  YMC엔터테인먼트, 스톤뮤직엔터테인먼트
# 10      뚜두뚜두   블랙핑크          4        그룹   2018-06-15               YG엔터테인먼트
# ...

# %%
# 인원수 기준으로 내림차순
df.sort_values('personnel', ascending=False).head() # 앞에 있는 5개 데이터만
# Out:
#        title singer  personnel sortation release_date                 agency  \
# 9       에너제틱    워너원         11        그룹   2017-08-07  YMC엔터테인먼트, 스톤뮤직엔터테인먼트
# 5    Ah-Choo   러블리즈          8        그룹   2015-10-01               울림엔터테인먼트
# 12  Dynamite  방탄소년단          7        그룹   2020-08-21                  빅히트뮤직
# 6       피땀눈물  방탄소년단          7        그룹   2016-10-10                  빅히트뮤직
# 7     시간을달려서   여자친구          6        그룹   2016-01-25                   쏘스뮤직
#
#    genre type
# 9     댄스   EP
# 5     댄스   EP
# 12    댄스   싱글
# 6    R&B   정규
# 7     댄스   EP

# %%
# 인원수와 가수명으로 오름차순 정렬
df.sort_values(['personnel','singer']).head()
# Out:
#       title singer  personnel sortation release_date     agency genre type
# 2     강남스타일     싸이          1        솔로   2012-07-15   YG엔터테인먼트    힙합   정규
# 0       좋은날    아이유          1        솔로   2010-12-09  카카오엔터테인먼트   발라드   EP
# 1   내가제일잘나가   2NE1          4        그룹   2011-06-24   YG엔터테인먼트    댄스   싱글
# 4       위아래   EXID          4        그룹   2014-08-27      바나나컬쳐    댄스   싱글
# 10     뚜두뚜두   블랙핑크          4        그룹   2018-06-15   YG엔터테인먼트    댄스   EP

# %%
# 인원수는 내림차로, 가수명은 오름차로 정렬해서 상위 5개의 데이터보기
df.sort_values(['personnel','singer'], ascending=[False,True]).head()
# Out:
#        title singer  personnel sortation release_date                 agency  \
# 9       에너제틱    워너원         11        그룹   2017-08-07  YMC엔터테인먼트, 스톤뮤직엔터테인먼트
# 5    Ah-Choo   러블리즈          8        그룹   2015-10-01               울림엔터테인먼트
# 6       피땀눈물  방탄소년단          7        그룹   2016-10-10                  빅히트뮤직
# 12  Dynamite  방탄소년단          7        그룹   2020-08-21                  빅히트뮤직
# 7     시간을달려서   여자친구          6        그룹   2016-01-25                   쏘스뮤직
#
#    genre type
# 9     댄스   EP
# 5     댄스   EP
# 6    R&B   정규
# 12    댄스   싱글
# 7     댄스   EP

# %% [markdown]
# ##### 3.1.9 데이터 빈도수 구하기

# %%
# 기획사(agency)별 빈도수 출력하기
cnt=df['agency'].value_counts() # 각 기획사 이름이 몇 번 나왔는지
pd.DataFrame(cnt)
# Out:
#                        count
# agency
# YG엔터테인먼트                   3
# 빅히트뮤직                      2
# SM엔터테인먼트                   2
# 카카오엔터테인먼트                  1
# 바나나컬쳐                      1
# 울림엔터테인먼트                   1
# 쏘스뮤직                       1
# YMC엔터테인먼트, 스톤뮤직엔터테인먼트      1
# JYP엔터테인먼트                  1

# %%
cnt=df['agency'].count()  # NaN 아닌 값이 총 몇 개인지 (ex: 13)
cnt
# Out:
# np.int64(13)

# %% [markdown]
# ##### 3.1.10 데이터 고유값 구하기

# %%
df['agency'].unique() # 칼럼의 고유값
# Out:
# array(['카카오엔터테인먼트', 'YG엔터테인먼트', 'SM엔터테인먼트', '바나나컬쳐', '울림엔터테인먼트', '빅히트뮤직',
#        '쏘스뮤직', 'YMC엔터테인먼트, 스톤뮤직엔터테인먼트', 'JYP엔터테인먼트'], dtype=object)

# %% [markdown]
# ### 3.4 데이터 선택하기

# %%
# 칼럼(열) 선택하기
filename = '/content/drive/MyDrive/data/weather.xlsx'
df=pd.read_excel(filename)
df.head()
# Out:
#           날짜  평균기온  최저기온  최고기온
# 0 2022-06-01  22.1  16.2  28.6
# 1 2022-06-02  21.5  17.1  26.9
# 2 2022-06-03  24.5  18.7  32.6
# 3 2022-06-04  25.6  20.3  29.7
# 4 2022-06-05  22.7  20.2  27.0

# %%
# 단일 칼럼 선택하기
df['평균기온'].head(10)
# Out:
# 0    22.1
# 1    21.5
# 2    24.5
# 3    25.6
# 4    22.7
# 5    19.7
# 6    20.6
# 7    21.2
# 8    20.9
# 9    20.9
# Name: 평균기온, dtype: float64

# %%
# 모든 행의 여러 칼럼 선택하기: []이용해서
df[['최저기온', '최고기온']].head(10)
# Out:
#    최저기온  최고기온
# 0  16.2  28.6
# 1  17.1  26.9
# 2  18.7  32.6
# 3  20.3  29.7
# 4  20.2  27.0
# 5  16.7  24.5
# 6  15.1  25.1
# 7  16.2  25.8
# 8  18.5  24.5
# 9  17.2  26.6

# %% [markdown]
# ### loc[]
#
# - 레이블이나 조건 표현으로 선택하는 방법: loc[]
# - 인덱스와 컬럼 이름으로 접근
# - 인덱스가 날짜나 문자열이라도 쓸 수 있음
# - 슬라이싱할 때 마지막 값도 포함됨!

# %%
# 모든 행의 여러 칼럼 선택하기: loc() 이용
df.loc[:, ['날짜', '최고기온']].head(10)
# Out:
#           날짜  최고기온
# 0 2022-06-01  28.6
# 1 2022-06-02  26.9
# 2 2022-06-03  32.6
# 3 2022-06-04  29.7
# 4 2022-06-05  27.0
# 5 2022-06-06  24.5
# 6 2022-06-07  25.1
# 7 2022-06-08  25.8
# 8 2022-06-09  24.5
# 9 2022-06-10  26.6

# %% [markdown]
# - loc[]는 범위를 지정할 때, 끝부분도 포함.
# - 보통 슬라이싱하면 [n:m]일 때, 출력은 [n:m-1]임
# - loc[]의 범위는 **[시작:끝] 범위**!

# %%
df.loc[0:3, ['날짜', '최고기온']] # loc는 0번부터 3번까지 다 출력함 why?
# Out:
#           날짜  최고기온
# 0 2022-06-01  28.6
# 1 2022-06-02  26.9
# 2 2022-06-03  32.6
# 3 2022-06-04  29.7

# %%
# 인덱스를 '날짜' 컬럼으로 지정 )
# 기존의 숫자 인덱스(0, 1, 2, ...)를 '날짜' 컬럼 값으로 바꾼경우
df.index=df['날짜']

# '2022-06-05'라는 인덱스 값(=행)을 기준으로 '최저기온', '최고기온' 선택
# 특정 날짜에 해당하는 컬럼 선택하기
df.loc['2022-06-05', ['최저기온', '최고기온']]
# Out:
# 최저기온    20.2
# 최고기온    27.0
# Name: 2022-06-05 00:00:00, dtype: object

# %%
# 평균기온이 25도 이상인 모든 행 전체를 선택
df.loc[df['평균기온']>=25]
# Out:
#                    날짜  평균기온  최저기온  최고기온
# 날짜
# 2022-06-04 2022-06-04  25.6  20.3  29.7
# 2022-06-20 2022-06-20  25.2  22.0  29.0
# 2022-06-21 2022-06-21  26.5  21.2  32.6
# 2022-06-22 2022-06-22  25.9  21.9  31.0
# 2022-06-25 2022-06-25  26.0  21.5  30.5
# 2022-06-26 2022-06-26  26.5  24.8  28.1
# 2022-06-27 2022-06-27  26.8  25.4  28.1
# 2022-06-28 2022-06-28  26.9  25.7  27.9
# 2022-06-29 2022-06-29  25.1  24.4  26.1

# %%
df.loc[df['평균기온']>=25,  ['최저기온', '최고기온']]
# Out:
#             최저기온  최고기온
# 날짜
# 2022-06-04  20.3  29.7
# 2022-06-20  22.0  29.0
# 2022-06-21  21.2  32.6
# 2022-06-22  21.9  31.0
# 2022-06-25  21.5  30.5
# 2022-06-26  24.8  28.1
# 2022-06-27  25.4  28.1
# 2022-06-28  25.7  27.9
# 2022-06-29  24.4  26.1

# %% [markdown]
# ##### 3.4.3 불 인덱싱

# %%
# 조건에 맞는 데이터 선택: []이용
w=df['최고기온']>30
df[w]
# Out:
#                    날짜  평균기온  최저기온  최고기온
# 날짜
# 2022-06-03 2022-06-03  24.5  18.7  32.6
# 2022-06-11 2022-06-11  24.6  17.7  32.7
# 2022-06-12 2022-06-12  24.6  18.9  31.5
# 2022-06-21 2022-06-21  26.5  21.2  32.6
# 2022-06-22 2022-06-22  25.9  21.9  31.0
# 2022-06-25 2022-06-25  26.0  21.5  30.5

# %%
# 조건에 맞는 행에서 특정 칼럼 선택: []이용
w=df['최고기온']>=30
df[w][['최저기온', '최고기온']]
# Out:
#             최저기온  최고기온
# 날짜
# 2022-06-03  18.7  32.6
# 2022-06-11  17.7  32.7
# 2022-06-12  18.9  31.5
# 2022-06-21  21.2  32.6
# 2022-06-22  21.9  31.0
# 2022-06-25  21.5  30.5

# %%
# 관계연산자도 쓸 수 있다
w=df['최고기온']==df['최고기온'].max()
# df[df['최고기온'] == df['최고기온'].max()] <- 이렇게도 가능!
df[w]
# Out:
#                    날짜  평균기온  최저기온  최고기온
# 날짜
# 2022-06-11 2022-06-11  24.6  17.7  32.7

# %%
# 일교차가 10도 이상인 데이터 출력
w=df['최고기온']-df['최저기온']>=10
df[w]
# Out:
#                    날짜  평균기온  최저기온  최고기온
# 날짜
# 2022-06-01 2022-06-01  22.1  16.2  28.6
# 2022-06-03 2022-06-03  24.5  18.7  32.6
# 2022-06-07 2022-06-07  20.6  15.1  25.1
# 2022-06-11 2022-06-11  24.6  17.7  32.7
# 2022-06-12 2022-06-12  24.6  18.9  31.5
# 2022-06-17 2022-06-17  22.5  16.5  28.1
# 2022-06-21 2022-06-21  26.5  21.2  32.6

# %% [markdown]
# ### 3.5 데이터 가공 및 그룹핑

# %%
filename='/content/drive/MyDrive/data/music.csv'
df=pd.read_csv(filename)
df.head()
# Out:
#      title singer  personnel sortation release_date     agency genre type
# 0      좋은날    아이유          1        솔로   2010-12-09  카카오엔터테인먼트   발라드   EP
# 1  내가제일잘나가   2NE1          4        그룹   2011-06-24   YG엔터테인먼트    댄스   싱글
# 2    강남스타일     싸이          1        솔로   2012-07-15   YG엔터테인먼트    힙합   정규
# 3     첫사랑니   f(x)          5        그룹   2013-07-29   SM엔터테인먼트    댄스   정규
# 4      위아래   EXID          4        그룹   2014-08-27      바나나컬쳐    댄스   싱글

# %% [markdown]
# ##### 3.5.1 칼럼 삭제
#
# drop() 메서드
# - 열을 삭제하는 메서드
# - pop과는 다르게 데이터프레임 원본이 변경되지 않는다.
# - inplace 옵션은 원본을 변경할지말지의 여부 -> True이면 원본 변경됨
# - axis=1은 삭제 대상이 열, axis=0은 삭제 대상이 행

# %%
# 데이터 분석에 필요없는 agency(기획사) 삭제
df.drop(columns=['agency'],axis=1, inplace=True)

# %%
df.columns # 열 확인하기
# Out:
# Index(['title', 'singer', 'personnel', 'sortation', 'release_date', 'genre',
#        'type'],
#       dtype='object')

# %% [markdown]
# ##### 3.5.2 칼럼 이름 변경

# %%
# 모든 컬럼 이름 변경하기
# 전체 변수 이름을 재설정
# 변수명을 차례로 재설정한다.
df.columns=['제목', '이름', '인원수', '구분', '발매일', '장르', '유형']
df.head()
# Out:
#         제목    이름  인원수  구분         발매일   장르  유형
# 0      좋은날   아이유    1  솔로  2010-12-09  발라드  EP
# 1  내가제일잘나가  2NE1    4  그룹  2011-06-24   댄스  싱글
# 2    강남스타일    싸이    1  솔로  2012-07-15   힙합  정규
# 3     첫사랑니  f(x)    5  그룹  2013-07-29   댄스  정규
# 4      위아래  EXID    4  그룹  2014-08-27   댄스  싱글

# %%
df.dtypes # 데이터타입을 보면 발매일은 숫자로 보이지만 사실 문자열임
# Out:
# 제목     object
# 이름     object
# 인원수     int64
# 구분     object
# 발매일    object
# 장르     object
# 유형     object
# dtype: object

# %%
df['발매일'] = pd.to_datetime(  df['발매일'], errors='coerce') # 발매일을 datetime64로 변경

# %%
df.dtypes # 다시 확인하면 시간 형태로 바뀜
# Out:
# 제목             object
# 이름             object
# 인원수             int64
# 구분             object
# 발매일    datetime64[ns]
# 장르             object
# 유형             object
# dtype: object

# %% [markdown]
# ##### 3.5.3 칼럼 생성

# %%
# 새로운 컬럼 생성하기: 년도, 월, 일
df['년도']=df['발매일'].dt.year # 발매일에서 연도만 추출해서 년도 컬럼으로 저장
df['월']=df['발매일'].dt.month # 발매일에서 월(month)만 추출
df['일']=df['발매일'].dt.day # 발매일에서 일(day)만 추출
df.head()
# Out:
#         제목    이름  인원수  구분        발매일   장르  유형    년도   월   일
# 0      좋은날   아이유    1  솔로 2010-12-09  발라드  EP  2010  12   9
# 1  내가제일잘나가  2NE1    4  그룹 2011-06-24   댄스  싱글  2011   6  24
# 2    강남스타일    싸이    1  솔로 2012-07-15   힙합  정규  2012   7  15
# 3     첫사랑니  f(x)    5  그룹 2013-07-29   댄스  정규  2013   7  29
# 4      위아래  EXID    4  그룹 2014-08-27   댄스  싱글  2014   8  27

# %% [markdown]
# ##### 3.5.4 데이터그룹핑

# %%
# 한 열을 기준으로 그룹화하기
# '인원수' 값이 존재하는 행의 개수
newdata = df.groupby('장르').count() # '장르' 컬럼을 기준으로 그룹화하고, NaN이 아닌 값의 개수를 모든 열에 대해 계산
pd.DataFrame(newdata['인원수'])
# newdata['인원수'] 랑 똑같음.
# 굳이 pd.DataFrame()으로 안 감싸도됨. 그냥 표 형태로 보기 위해서 감싸는 것일뿐
# Out:
#      인원수
# 장르
# R&B    1
# 댄스    10
# 발라드    1
# 힙합     1

# %%
print(df.dtypes)
# Out:
# 제목             object
# 이름             object
# 인원수             int64
# 구분             object
# 발매일    datetime64[ns]
# 장르             object
# 유형             object
# 년도              int32
# 월               int32
# 일               int32
# dtype: object

# %%
df
# Out:
#           제목     이름  인원수  구분        발매일   장르  유형    년도   월   일
# 0        좋은날    아이유    1  솔로 2010-12-09  발라드  EP  2010  12   9
# 1    내가제일잘나가   2NE1    4  그룹 2011-06-24   댄스  싱글  2011   6  24
# 2      강남스타일     싸이    1  솔로 2012-07-15   힙합  정규  2012   7  15
# 3       첫사랑니   f(x)    5  그룹 2013-07-29   댄스  정규  2013   7  29
# 4        위아래   EXID    4  그룹 2014-08-27   댄스  싱글  2014   8  27
# 5    Ah-Choo   러블리즈    8  그룹 2015-10-01   댄스  EP  2015  10   1
# 6       피땀눈물  방탄소년단    7  그룹 2016-10-10  R&B  정규  2016  10  10
# 7     시간을달려서   여자친구    6  그룹 2016-01-25   댄스  EP  2016   1  25
# 8        빨간맛   레드벨벳    5  그룹 2017-07-09   댄스  EP  2017   7   9
# 9       에너제틱    워너원   11  그룹 2017-08-07   댄스  EP  2017   8   7
# 10      뚜두뚜두   블랙핑크    4  그룹 2018-06-15   댄스  EP  2018   6  15
# 11      달라달라     있지    5  그룹 2019-02-12   댄스  싱글  2019   2  12
# 12  Dynamite  방탄소년단    7  그룹 2020-08-21   댄스  싱글  2020   8  21

# %%
# 여러 열을 기준으로 그룹화하기
newdata = df.groupby(['구분', '장르']).sum() # 구분과 장르로 그룹핑한다음 합계 출력하기
pd.DataFrame(newdata['인원수'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-5c71f84022ef> in <cell line: 0>()
#       1 # 여러 열을 기준으로 그룹화하기
# ----> 2 newdata = df.groupby(['구분', '장르']).sum() # 구분과 장르로 그룹핑한다음 합계 출력하기
#       3 pd.DataFrame(newdata['인원수'])
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in sum(self, numeric_only, min_count, engine, engine_kwargs)
#    3144             # _agg_general() returns. GH #31422
#    3145             with com.temp_setattr(self, "observed", True):
# -> 3146                 result = self._agg_general(
#    3147                     numeric_only=numeric_only,
#    3148                     min_count=min_count,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in _agg_general(self, numeric_only, min_count, alias, npfunc, **kwargs)
#    1904         **kwargs,
#    1905     ):
# ...

# %% [markdown]
# ### 3.6 결측치 처리하기
#
# - 누락된 데이터 표시: NaN(Not a Number)
# - 연산 시 포함x

# %%
# 타이타닉 데이터 불러오기
filename='/content/drive/MyDrive/data/train.csv'
df=pd.read_csv(filename)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ##### 3.6.1 결측 데이터 확인
#
# - isnull()과 isna()는 완전히 같음

# %%
df.info()
# age도 누락되어있고, Cabin(객실 번호)도 누락이 많이 되어있다.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# 결츨데이터 확인: 탑승항구(Embarked)에 결측치가 있는 행 반환
df[df['Embarked'].isnull()]
# 결과: 누락된 행의 개수는 2개
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %% [markdown]
# isnull()
# - 결측 데이터이면 True, 유효한 데이터라면 False 반환
# - isna ()와 동일

# %%
# 칼럼별 결측 데이터 개수 확인
df.isnull().sum()
# df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# 위에서 결과를 확인해보면 Cabin(객실번호)는 누락이 많이 되어있다. 그래서 .head(20) 으로 일부만 보기

# %%
# 결측데이터 확인: 객실번호(Cabin) 결측 데이터
df[df['Cabin'].isnull()].head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 2             3         1       3
# 4             5         0       3
# 5             6         0       3
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 22           23         1       3
# 24           25         0       3
# 25           26         1       3
# 26           27         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# ...

# %% [markdown]
# #####3.6.2 결측데이터 삭제

# %%
# 데이터 삭제 -
df.drop('Cabin', axis=1, inplace=True)
# axis=1 : 열 선택
# inplace=True : 원본 df에서 바로 삭제 반영

# %% [markdown]
# Cabin은 누락데이터가 너무 많아서 그냥 삭제하기로 결정
# 아래의 코드로 제대로 누락되었나 확인

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ##### 3.6.3 결측데이터 대체: 최빈값으로 채우기

# %%
# Embarked열의 최빈값 찾기
df['Embarked'].mode()
# 탑승항구의 최빈값은 s임
# Out:
# 0    S
# Name: Embarked, dtype: object

# %% [markdown]
# .fillna()
# - fill NaN의 줄임말 = 결측치(NaN)를 채운다는 뜻
#
#
# - df['Embarked'].mode() : 'Embarked' 컬럼에서 가장 많이 나온 값을 리스트처럼 반환 (예: ['S'])
# - [0] : 가장 첫 번째 최빈값 선택 (최빈값이 여러 개일 경우 대비)
# - .fillna(..., inplace=True) : 결측치(NaN)를 최빈값으로 채우고, inplace=True니까 원본 df가 직접 바뀜

# %%
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True) # 결측치 채우고
df.isnull().sum() # 결과 확인
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# dtype: int64

# %% [markdown]
# 결과보면 Embarked가 0이다!

# %%
# 평균값으로 대체
avg=df['Age'].mean() # 나이의 평균값을 구해
df['Age']=df['Age'].fillna(avg) # 평균값으로 대체
# df['Age].fillna(avg, inplace=True) 와 같음

# 결과를 보면 age가 0으로 되어있음
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64
